# %%
#using Pkg
#Pkg.add(["DataArrays","DataFrames","Plots","CSV"])
using DataFrames, Plots, CSV
function myprint(Obj)
    show(stdout, "text/plain", Obj)
end
# Out:
# myprint (generic function with 1 method)

# %%
df = DataFrame!(CSV.File("Deliveries.txt", normalizenames = true))

for i in 2:5
    select!(df, Not(findall(occursin.("Fielder"*string(i), names(df)))))
end
for name in names(df)
    u = unique(df[!,name])
    if length(u) == 1
        select!(df, Not(name))
    end
end

df = df[df.Striker_Hand.=="Right",:]
df = df[df.Bowler_Hand.=="Right",:]
df = df[df.Over_The_Wicket.=="Y",:]
df = df[df.Wides.>0,:]

select!(df, Not([
        "Match_YYMMDD",
        "TeamA_At_Home",
        "Toss_Won_By_Id",
        "TeamA_ResultId",
        "Team_Batting_Id",
        "Time_of_Day_Hour_",
        "Time_of_Day_Min_",
        "Striker_Id",
        "Striker_Hand_Id",
        "Non_Striker_Id",
        "Bowler_Id",
        "Bowler_Hand_Id",
        "Batter_Out_Id",
        "Fielder1_Id",
        "TeamA_Id", 
        "TeamB_Result",
        "Team_Bowling_Result", 
        "Individual_100",
        "Partnership_50",
        "Partnership_100", 
        "Partnership_150", 
        "Event_Grade", 
        "Event_Infield",
        "TeamB_Id",
        "TeamBattingIdMatchInnings1",
        "TeamBattingIdMatchInnings2",
        "TeamBattingIdMatchInnings3",
        "TeamBattingIdMatchInnings4",
        "TeamB_ResultId",
        "Team_Batting_ResultId",
        "Team_Bowling_ResultId",
        "Individual_50",
        "Injury_Striker_Other",           
        "Injury_Bowler_Other_1",          
        "Injury_Fielder_Other",
        "Cum_Inning_Noball_Runs",         
        "Cum_Inning_Wides",               
        "Cum_Inning_Wide_Runs",           
        "Cum_Inning_Byes",                
        "Cum_Inning_Legbyes",             
        "Cum_Inning_Extras",                             
        "Cum_Inning_Wickets",                
        "At_Batter_X_Coded",              
        "At_Batter_Y_Coded",
        "Time_of_Day_Sec_",               
        "Video_Start_Time_UTC",           
        "Video_Stop_Time_UTC",            
        "Video_UTC_Offset_Minutes",       
        "Video_Start_Time_Local",         
        "Video_Stop_Time_Local",
        ]))
df
# Out:
# 314×152 DataFrame. Omitted printing of 148 columns
# │ Row │ Match_Id │ Match_Date  │ Day_Night │ Venue_Id │
# │     │ Int64    │ String      │ String    │ Int64    │
# ├─────┼──────────┼─────────────┼───────────┼──────────┤
# │ 1   │ 3551019  │ 18-Oct-2019 │ N         │ 6        │
# │ 2   │ 3551019  │ 18-Oct-2019 │ N         │ 6        │
# │ 3   │ 3551019  │ 18-Oct-2019 │ N         │ 6        │
# │ 4   │ 3551019  │ 18-Oct-2019 │ N         │ 6        │
# │ 5   │ 3551019  │ 18-Oct-2019 │ N         │ 6        │
# │ 6   │ 3551019  │ 18-Oct-2019 │ N         │ 6        │
# │ 7   │ 3551020  │ 19-Oct-2019 │ N         │ 2950004  │
# │ 8   │ 3551020  │ 19-Oct-2019 │ N         │ 2950004  │
# │ 9   │ 3551020  │ 19-Oct-2019 │ N         │ 2950004  │
# │ 10  │ 3551020  │ 19-Oct-2019 │ N         │ 2950004  │
# ⋮
# │ 304 │ 4390117  │ 07-Dec-2019 │ N         │ 1002     │
# │ 305 │ 4390117  │ 07-Dec-2019 │ N         │ 1002     │
# │ 306 │ 4390117  │ 07-Dec-2019 │ N         │ 1002     │
# │ 307 │ 4390117  │ 07-Dec-2019 │ N         │ 1002     │
# │ 308 │ 4390118  │ 07-Dec-2019 │ N         │ 1002     │
# │ 309 │ 4390118  │ 07-Dec-2019 │ N         │ 1002     │
# │ 310 │ 4390125  │ 08-Dec-2019 │ N         │ 1002     │
# │ 311 │ 4390125  │ 08-Dec-2019 │ N         │ 1002     │
# │ 312 │ 4390125  │ 08-Dec-2019 │ N         │ 1002     │
# │ 313 │ 4390125  │ 08-Dec-2019 │ N         │ 1002     │
# │ 314 │ 4390125  │ 08-Dec-2019 │ N         │ 1002     │

# %%
myprint(names(df))
# Out:
# 152-element Array{String,1}:
#  "Match_Id"
#  "Match_Date"
#  "Day_Night"
#  "Venue_Id"
#  "Venue"
#  "TeamB_At_Home"
#  "Team_Batting_At_Home"
#  "Team_Bowling_At_Home"
#  "Toss_Won_By_Team"
#  "Toss_Won_By_Batting_Team"
#  "Toss_Decision"
#  "TeamA_Innings1_Closure"
#  "TeamA_Innings2_Closure"
#  "TeamB_Innings1_Closure"
#  "TeamB_Innings2_Closure"
#  "TeamA_1st_Comparison"
#  "TeamA_Result"
#  "Team_Batting"
#  "Team_Bowling_Id"
#  "Team_Bowling"
#  "Innings"
#  "Delivery"
#  "Session"
#  "Time_of_Day"
#  "Striker"
#  "Striker_Hand"
#  "Non_Striker"
#  "Non_Striker_Hand_Id"
#  "Non_Striker_Hand"
#  "Bowler"
#  "Bowler_Hand"
#  "Pace_Spin"
#  "Bowler_Style"
#  "Spell"
#  "Over_The_Wicket"
#  "Northern_End"
#  "Power_Play"
#  "Over"
#  "Ball_In_Over"
#  "Fair_Ball_In_Over"
#  "Ball_Speed"
#  "Pitch_X"
#  "Pitch_Y"
#  "At_Batter_X"
#  "At_Batter_Y"
#  "At_Stumps_X"
#  "At_Stumps_Y"
#  "Hit_To_Len"
#  "Hit_To_Angle"
#  "Bat_Score"
#  "ReachedBoundary"
#  "Wides"
#  "Noballs"
#  "Byes"
#  "Legbyes"
#  "Taken_By_WK"
#  "Batter_Out"
#  "How_Out"
#  "Fielder1"
#  "TeamA"
#  "TeamB"
#  "TeamBattingMatchInnings1"
#  "TeamBattingMatchInnings2"
#  "TeamBattingMatchInnings3"
#  "TeamBattingMatchInnings4"
#  "MatchInnings"
#  "Team_Batting_Result"
#  "Temperature_Id"
#  "Temperature_Description"
#  "Humidity_Id"
#  "Humidity_Description"
#  "Wind_Id"
#  "Wind_Description"
#  "Cloud_Cover_Id"
#  "Cloud_Cover_Description"
#  "Cloud_Colour_Id"
#  "Cloud_Colour_Description"
#  "Inside_Edge"
#  "Outside_Edge"
#  "Play_and_Miss"
#  "Hit_on_Pads"
#  "Hit_on_Head"
#  "Hit_on_Body"
#  "Contact_Error"
#  "Opportunity"
#  "Appeal"
#  "Bowler_Variation"
#  "Batter_Movement"
#  "Sweep_Shot"
#  "Ramp_or_Paddle_Shot"
#  "Reverse_or_Switch_Shot"
#  "Umpire_Referral"
#  "DRS_Bowler_Won"
#  "Fielder1_Catch"
#  "Fielder1_Catch_Assist"
#  "Fielder1_Dropped_Catch"
#  "Fielder1_Runout"
#  "Fielder1_Runout_Missed"
#  "Fielder1_Runout_Assist"
#  "Fielder1_Runout_Assist_Missed"
#  "Fielder1_Missed_Stumping"
#  "Fielder1_Extra_Effort"
#  "Fielder1_Pressure_Field"
#  "Fielder1_Assist"
#  "Fielder1_Fumble"
#  "Fielder1_Misfield"
#  "Fielder1_Dive_Stop"
#  "Fielder1_Dive_Misfield"
#  "Fielder1_Slide_Stop"
#  "Fielder1_Slide_Miss"
#  "Fielder1_Throw"
#  "Fielder1_Good_Throw"
#  "Fielder1_Error_Throw"
#  "Fielder1_Throw_Hit"
#  "Fielder1_Throw_Miss"
#  "Fielder1_Throw_Backed_Up"
#  "Fielder1_Throw_Not_Backed_Up"
#  "Fielder1_Keeper_Drop"
#  "Fielder1_Keeper_Fumble"
#  "Fielder1_Keeper_Dive_Stop"
#  "Fielder1_Keeper_Missed_Stumping"
#  "Fielder1_Keeper_Leg_Side"
#  "Fielder1_Event_Grade"
#  "Fielder1_Event_Infield"
#  "Fielder1_Runs_Cost"
#  "Fielder1_Runs_Saved"
#  "Cum_Inning_Balls"
#  "Cum_Inning_Bat_Score"
#  "Cum_Inning_Noballs"
#  "Cum_Inning_Score"
#  "Cum_Striker_Balls"
#  "Cum_Striker_Runs"
#  "Cum_Non_Striker_Balls"
#  "Cum_Non_Striker_Runs"
#  "Cum_Partnership_Balls"
#  "Cum_Partnership_Runs"
#  "Cum_Bowler_Balls"
#  "Cum_Bowler_Runs"
#  "Pitch_X_Coded"
#  "Pitch_Y_Coded"
#  "Free_Hit"
#  "Data_Source"
#  "Time_of_Day_Full_"
#  "Striker_Batting_Position"
#  "Non_Striker_Batting_Position"
#  "Bowler_Bowling_Position"
#  "Hit_To_Octant"
#  "Hit_To_Octant_Description"
#  "Pitch_X_Description"
#  "Pitch_Y_Description"
#  "Pitch_X_Coded_Description"
#  "Pitch_Y_Coded_Description"

# %%
allowmissing!(df)
df.Pitch_X[df.Pitch_X.<-10000] .= missing
df.Pitch_Y[df.Pitch_Y.<-10000] .= missing
# Out:
# 0-element view(::Array{Union{Missing, Int64},1}, Int64[]) with eltype Union{Missing, Int64}

# %%
pitchxdataN = df.Pitch_X_Coded[df.Northern_End.=="N"].-304.8
pitchydataN = df.Pitch_Y_Coded[df.Northern_End.=="N"]
pitchxdataS = df.Pitch_X_Coded[df.Northern_End.=="S"].-304.8
pitchydataS = df.Pitch_Y_Coded[df.Northern_End.=="S"]

plot(legend=false)
plot!([-1500,1500],[22560/2,22560/2],color=:black)
plot!([-1500,1500],[-22560/2,-22560/2],color=:black)
plot!([-1500,1500],[22560/2-1220,22560/2-1220],color=:black)
plot!([-1500,1500],[-22560/2+1220,-22560/2+1220],color=:black)
#plot!([-2640/2,-2640/2],[-25000/2,25000/2],color=:black)
#plot!([2640/2,2640/2],[-25000/2,25000/2],color=:black)
plot!([-304.8,-304.8],[-25000/2,25000/2],color=:black)
plot!([304.8,304.8],[-25000/2,25000/2],color=:black)
plot!([1320-431.8,1320-431.8],[-25000/2,25000/2],color=:black)
plot!([-1320+431.8,-1320+431.8],[-25000/2,25000/2],color=:black)
scatter!(pitchxdataN, pitchydataN, color = df.Wides)
scatter!(pitchxdataS, pitchydataS, color = df.Wides)

# %%
atbatterxdata = df.At_Batter_X.-304.8
atbatterydata = df.At_Batter_Y

plot(legend=false)
plot!([-228.6/2,228.6/2],[711.2,711.2], color = :black)
plot!([-228.6/2,-228.6/2],[0,711.2], color = :black)
plot!([228.6/2,228.6/2],[0,711.2], color = :black)
plot!([304.8,304.8],[-10,2000], color = :black)
plot!([-304.8,-304.8],[-10,2000], color = :black)
plot!([1320-431.8,1320-431.8],[-10,2000], color = :black)
plot!([-1320+431.8,-1320+431.8],[-10,2000], color = :black)
scatter!(atbatterxdata, atbatterydata, color = df.Wides)

# %%
atstumpsxdata = df.At_Stumps_X[.!ismissing.(df.Data_Source)].-304.8
atstumpsydata = df.At_Stumps_Y[.!ismissing.(df.Data_Source)]

plot(legend=false)
plot!([-228.6/2,228.6/2],[711.2,711.2], color = :black)
plot!([-228.6/2,-228.6/2],[0,711.2], color = :black)
plot!([228.6/2,228.6/2],[0,711.2], color = :black)
plot!([304.8,304.8],[-10,2000], color = :black)
plot!([-304.8,-304.8],[-10,2000], color = :black)
scatter!(atstumpsxdata, atstumpsydata, color = df.Wides)

# %%
hittox = df.Hit_To_Len.*sin.(df.Hit_To_Angle)
hittoy = df.Hit_To_Len.*cos.(df.Hit_To_Angle)
hittoxdata = [zeros(size(hittox)) hittox]'
hittoydata = [zeros(size(hittoy)) hittoy]'
plot(legend=false)
plot!(hittoxdata, hittoydata, color = df.Bat_Score')
